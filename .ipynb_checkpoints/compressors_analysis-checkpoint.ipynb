# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import datetime
from pandas import DataFrame

from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %matplotlib inline
import os

# %%
print(os.listdir())
# Out:
# ['.git', '.ipynb_checkpoints', 'compressors_analysis.ipynb', 'data']

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# В оригинальном дщокументе два листа с данными за разные временные интервалы. На первом листе данные с 10.06.2020 по
# 23.06.2020. На втором листе данные с 22.05.202 по 10.06.2020.
#
# В оригинальном документе убираем все фильтры и поочередно сохраняем каждый лист в csv файл с разделителем полей "," и разделителем строк ". Используем для сохранения кодировку UTF-8. Сохраняю файлы с помощью LibreOffice в Linux Mint.
# Соответственно получаем два файла:

# %%
for file in os.listdir("./data"):
    if "csv" in file:
        print(file)
# Out:
# 10.06.2020-23.06.2020.csv
# 10.06.2020-23.06.2020_old.csv
# 10.06_filter.csv
# 22.05.2020-10.06.2020.csv
# 22.05.2020-10.06.2020_old.csv
# 26.05_filter.csv

# %%
df_22_05 = pd.read_csv("./data/22.05.2020-10.06.2020.csv")
df_10_06 = pd.read_csv("./data/10.06.2020-23.06.2020.csv")
df_22_05
# Out:
#             Время срабатывания         Квитировать  \
# 0      10.06.2020 06:18:31.764      Не квитировано
# 1      10.06.2020 06:18:31.715      Не квитировано
# 2      10.06.2020 06:18:31.534      Не квитировано
# 3      10.06.2020 06:18:31.534      Не квитировано
# 4      10.06.2020 06:18:04.932      Не квитировано
# ...                        ...                 ...
# 11026  22.05.2020 06:40:40.067  01.06.2020 5:26:58
# 11027  22.05.2020 06:40:40.067  01.06.2020 5:26:58
# 11028  22.05.2020 06:40:40.067  01.06.2020 5:26:58
# 11029  22.05.2020 06:40:40.067  01.06.2020 5:26:58
# 11030  22.05.2020 06:40:31.867      Не квитировано
#
#                                                Сообщение
# 0                             Компрессор К-113. ОТКЛЮЧЕН
# 1                           Вентилятор АТ-102/1. ВКЛЮЧЕН
# 2                    Соленоидный клапан К112-СR2. ЗАКРЫТ
# 3      Соленоидный клапан К112-СR2. ПОЛУЧЕНА КОМАНДА ...
# 4                    Соленоидный клапан К113-СR1. ЗАКРЫТ
# ...                                                  ...
# 11026  PT-911. Давление паров на входе вентиляторов V...
# 11027  PT-911. Давление паров на входе вентиляторов V...
# 11028  PT-911. Давление паров на входе вентиляторов V...
# 11029  PT-911. Давление паров на входе вентиляторов V...
# 11030  PT-911. Давление паров на входе вентиляторов V...
#
# [11031 rows x 3 columns]

# %%
df_10_06
# Out:
#             Время срабатывания     Квитировать  \
# 0      23.06.2020 05:47:37.951  Не квитировано
# 1      23.06.2020 05:47:37.101  Не квитировано
# 2      23.06.2020 05:47:37.101  Не квитировано
# 3      23.06.2020 05:47:37.101  Не квитировано
# 4      23.06.2020 05:47:32.225  Не квитировано
# ...                        ...             ...
# 64995  10.06.2020 06:18:31.015  Не квитировано
# 64996  10.06.2020 06:18:30.617  Не квитировано
# 64997  10.06.2020 06:18:29.917  Не квитировано
# 64998  10.06.2020 06:18:31.864  Не квитировано
# 64999  10.06.2020 06:18:31.834  Не квитировано
#
#                                                Сообщение
# 0                           Вентилятор АТ-101/1. ВКЛЮЧЕН
# 1      Вентилятор АТ-101/1. КОМАНДА - ВКЛЮЧИТЬ РЕЗЕРВ...
# 2           Вентилятор АТ-101/1. НАЗНАЧЕН РЕЖИМ ОСНОВНОЙ
# 3      Вентилятор АТ-101/1. НАЗНАЧИТЬ РЕЖИМ ОСНОВНОЙ ...
# 4      Соленоидный клапан К112-СR1. ПОЛУЧЕНА КОМАНДА ...
# ...                                                  ...
# 64995  Вентилятор АТ-102/1. КОМАНДА - ВКЛЮЧИТЬ РЕЗЕРВ...
# 64996                       Вентилятор АТ-111/3. ВКЛЮЧЕН
# 64997  Вентилятор АТ-111/3. КОМАНДА - ВКЛЮЧИТЬ АВТОМА...
# 64998         Компрессор К-113. НАЗНАЧЕН РЕЖИМ РЕЗЕРВНЫЙ
# 64999                         Компрессор К-113. ЗАДЕРЖКА
#
# [65000 rows x 3 columns]

# %% [markdown]
# Очевидно разбивка на два листа не имеет смылса и вызвана только техническим ограницением excel в 65000 строк. Обьединим
# два датафрейма в один в хронологическом порядке.

# %%
df_all = pd.concat([df_10_06, df_22_05], ignore_index=True)
df_all
# Out:
#             Время срабатывания         Квитировать  \
# 0      23.06.2020 05:47:37.951      Не квитировано
# 1      23.06.2020 05:47:37.101      Не квитировано
# 2      23.06.2020 05:47:37.101      Не квитировано
# 3      23.06.2020 05:47:37.101      Не квитировано
# 4      23.06.2020 05:47:32.225      Не квитировано
# ...                        ...                 ...
# 76026  22.05.2020 06:40:40.067  01.06.2020 5:26:58
# 76027  22.05.2020 06:40:40.067  01.06.2020 5:26:58
# 76028  22.05.2020 06:40:40.067  01.06.2020 5:26:58
# 76029  22.05.2020 06:40:40.067  01.06.2020 5:26:58
# 76030  22.05.2020 06:40:31.867      Не квитировано
#
#                                                Сообщение
# 0                           Вентилятор АТ-101/1. ВКЛЮЧЕН
# 1      Вентилятор АТ-101/1. КОМАНДА - ВКЛЮЧИТЬ РЕЗЕРВ...
# 2           Вентилятор АТ-101/1. НАЗНАЧЕН РЕЖИМ ОСНОВНОЙ
# 3      Вентилятор АТ-101/1. НАЗНАЧИТЬ РЕЖИМ ОСНОВНОЙ ...
# 4      Соленоидный клапан К112-СR1. ПОЛУЧЕНА КОМАНДА ...
# ...                                                  ...
# 76026  PT-911. Давление паров на входе вентиляторов V...
# 76027  PT-911. Давление паров на входе вентиляторов V...
# 76028  PT-911. Давление паров на входе вентиляторов V...
# 76029  PT-911. Давление паров на входе вентиляторов V...
# 76030  PT-911. Давление паров на входе вентиляторов V...
#
# [76031 rows x 3 columns]

# %% [markdown]
# Посмотрим на строку сообщение

# %%
df_all["Сообщение"][0]
# Out:
# 'Вентилятор АТ-101/1. ВКЛЮЧЕН'

# %% [markdown]
# Видим что имя компонента, к которому относится сообщение отделено от сообщения точкой.
# Создадим новый датафрейм из столбца "Сообщение" используя в качестве разделителя точку. опция expand=True
# сразу проведет разбиение на колонки

# %%
df_all_splited = df_all["Сообщение"].str.split('.', expand=True)

# %% [markdown]
# Переименуем колонки полученого датафрейма df_all_splited

# %%
df_all_splited.columns = ['component', 'm0', 'm1', 'm2', 'm3', 'm4']
df_all_splited
# Out:
#                          component  \
# 0              Вентилятор АТ-101/1
# 1              Вентилятор АТ-101/1
# 2              Вентилятор АТ-101/1
# 3              Вентилятор АТ-101/1
# 4      Соленоидный клапан К112-СR1
# ...                            ...
# 76026                       PT-911
# 76027                       PT-911
# 76028                       PT-911
# 76029                       PT-911
# 76030                       PT-911
#
#                                                       m0  \
# 0                                                ВКЛЮЧЕН
# 1       КОМАНДА - ВКЛЮЧИТЬ РЕЗЕРВНЫЙ АГРЕГАТ КАК ДОПО...
# 2                                НАЗНАЧЕН РЕЖИМ ОСНОВНОЙ
# 3                 НАЗНАЧИТЬ РЕЖИМ ОСНОВНОЙ АВТОМАТИЧЕСКИ
# 4               ПОЛУЧЕНА КОМАНДА "ОТКРЫТЬ АВТОМАТИЧЕСКИ"
# ...                                                  ...
# 76026   Давление паров на входе вентиляторов VD-103/A...
# 76027   Давление паров на входе вентиляторов VD-103/A...
# 76028   Давление паров на входе вентиляторов VD-103/A...
# 76029   Давление паров на входе вентиляторов VD-103/A...
# 76030   Давление паров на входе вентиляторов VD-103/A...
#
#                              m1    m2    m3    m4
# 0                          None  None  None  None
# 1                          None  None  None  None
# 2                          None  None  None  None
# 3                          None  None  None  None
# 4                          None  None  None  None
# ...                         ...   ...   ...   ...
# 76026   «Минимум предаварийный»  None  None  None
# 76027       «Минимум аварийный»  None  None  None
# 76028                ДОСТОВЕРЕН  None  None  None
# 76029                 «Минимум»  None  None  None
# 76030           НЕДОСТОВЕРНОСТЬ   ВПД  None  None
#
# [76031 rows x 6 columns]

# %% [markdown]
# Смерджим датафрейм df_all и датафрейм df_all_splited

# %%
df_fin = pd.concat([df_all, df_all_splited], axis = 1)
df_fin
# Out:
#             Время срабатывания         Квитировать  \
# 0      23.06.2020 05:47:37.951      Не квитировано
# 1      23.06.2020 05:47:37.101      Не квитировано
# 2      23.06.2020 05:47:37.101      Не квитировано
# 3      23.06.2020 05:47:37.101      Не квитировано
# 4      23.06.2020 05:47:32.225      Не квитировано
# ...                        ...                 ...
# 76026  22.05.2020 06:40:40.067  01.06.2020 5:26:58
# 76027  22.05.2020 06:40:40.067  01.06.2020 5:26:58
# 76028  22.05.2020 06:40:40.067  01.06.2020 5:26:58
# 76029  22.05.2020 06:40:40.067  01.06.2020 5:26:58
# 76030  22.05.2020 06:40:31.867      Не квитировано
#
#                                                Сообщение  \
# 0                           Вентилятор АТ-101/1. ВКЛЮЧЕН
# 1      Вентилятор АТ-101/1. КОМАНДА - ВКЛЮЧИТЬ РЕЗЕРВ...
# 2           Вентилятор АТ-101/1. НАЗНАЧЕН РЕЖИМ ОСНОВНОЙ
# 3      Вентилятор АТ-101/1. НАЗНАЧИТЬ РЕЖИМ ОСНОВНОЙ ...
# 4      Соленоидный клапан К112-СR1. ПОЛУЧЕНА КОМАНДА ...
# ...                                                  ...
# 76026  PT-911. Давление паров на входе вентиляторов V...
# 76027  PT-911. Давление паров на входе вентиляторов V...
# 76028  PT-911. Давление паров на входе вентиляторов V...
# 76029  PT-911. Давление паров на входе вентиляторов V...
# 76030  PT-911. Давление паров на входе вентиляторов V...
#
#                          component  \
# 0              Вентилятор АТ-101/1
# 1              Вентилятор АТ-101/1
# 2              Вентилятор АТ-101/1
# 3              Вентилятор АТ-101/1
# 4      Соленоидный клапан К112-СR1
# ...                            ...
# 76026                       PT-911
# 76027                       PT-911
# 76028                       PT-911
# 76029                       PT-911
# 76030                       PT-911
#
#                                                       m0  \
# 0                                                ВКЛЮЧЕН
# 1       КОМАНДА - ВКЛЮЧИТЬ РЕЗЕРВНЫЙ АГРЕГАТ КАК ДОПО...
# 2                                НАЗНАЧЕН РЕЖИМ ОСНОВНОЙ
# 3                 НАЗНАЧИТЬ РЕЖИМ ОСНОВНОЙ АВТОМАТИЧЕСКИ
# 4               ПОЛУЧЕНА КОМАНДА "ОТКРЫТЬ АВТОМАТИЧЕСКИ"
# ...                                                  ...
# 76026   Давление паров на входе вентиляторов VD-103/A...
# 76027   Давление паров на входе вентиляторов VD-103/A...
# 76028   Давление паров на входе вентиляторов VD-103/A...
# 76029   Давление паров на входе вентиляторов VD-103/A...
# 76030   Давление паров на входе вентиляторов VD-103/A...
#
#                              m1    m2    m3    m4
# 0                          None  None  None  None
# 1                          None  None  None  None
# 2                          None  None  None  None
# 3                          None  None  None  None
# 4                          None  None  None  None
# ...                         ...   ...   ...   ...
# 76026   «Минимум предаварийный»  None  None  None
# 76027       «Минимум аварийный»  None  None  None
# 76028                ДОСТОВЕРЕН  None  None  None
# 76029                 «Минимум»  None  None  None
# 76030           НЕДОСТОВЕРНОСТЬ   ВПД  None  None
#
# [76031 rows x 9 columns]

# %% [markdown]
# Посмотрим форму финального датафрейма

# %%
df_fin.shape
# 76031 строк
# 9 столбцов
# Out:
# (76031, 9)

# %%
df_fin.index
df_fin["Время срабатывания"] = pd.to_datetime(df_fin['Время срабатывания'])
df_fin["Время срабатывания"]
# Out:
# 0       2020-06-23 05:47:37.951
# 1       2020-06-23 05:47:37.101
# 2       2020-06-23 05:47:37.101
# 3       2020-06-23 05:47:37.101
# 4       2020-06-23 05:47:32.225
#                   ...
# 76026   2020-05-22 06:40:40.067
# 76027   2020-05-22 06:40:40.067
# 76028   2020-05-22 06:40:40.067
# 76029   2020-05-22 06:40:40.067
# 76030   2020-05-22 06:40:31.867
# Name: Время срабатывания, Length: 76031, dtype: datetime64[ns]

# %%
plt.style.use('fivethirtyeight')

# %%
x = np.linspace(0, 10, 76031)
x
# Out:
# array([0.00000000e+00, 1.31527029e-04, 2.63054058e-04, ...,
#        9.99973695e+00, 9.99986847e+00, 1.00000000e+01])

# %%
y = np.sin(x) + dy * np.random.randn(50)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-391230ebc190> in <module>
# ----> 1 y = np.sin(x) + dy * np.random.randn(50)
#
# NameError: name 'dy' is not defined

# %%
plt.figure(figsize=(20, 10))
plt.plot(x + 6, df_fin["Время срабатывания"])
plt.title("Частота по времени")
plt.xlabel("Время")
plt.ylabel("Значение")
# Out:
# Text(0, 0.5, 'Значение')

# %%
#df_fin_tf = df_fin
df_fin["temp"] = df_fin.m0 == "ПУСК НЕВОЗМОЖЕН"
#df["pop"] = np.where(df["pop"] > 2, 3.7 + df.index, df["pop"]*1.1)
df_fin["temp"]

# df["temp"] = df.state == "Ohio"
# df["pop"] = np.where(df["pop"] > 2, 3.7 + df.index, df["pop"]*1.1)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 76026    False
# 76027    False
# 76028    False
# 76029    False
# 76030    False
# Name: temp, Length: 76031, dtype: bool

# %%
df_fin.groupby("temp").count()
# Out:
#        Время срабатывания  Квитировать  Сообщение  component     m0     m1  \
# temp
# False               76031        76031      76031      76031  75991  35193
#
#          m2   m3  m4
# temp
# False  4227  591  36

# %%
df_fin.groupby("m0").count().tail(60)
# Out:
#                                                     Время срабатывания  \
# m0
#  Нажата кнопка маскировать сигнал: Отсутствие а...                   1
#  Низкое давление на линии всасывания по датчику                     67
#  Низкое давление на линии всасывания по реле                        16
#  Низкое давление на линии подачи масла по реле                       5
#  ОТКЛЮЧЕН                                                         5400
#  ОТКРЫВАЕТСЯ                                                       127
#  ОТКРЫВАЕТСЯ В РЕЖИМЕ ИМИТАЦИИ                                       5
#  ОТКРЫТ                                                           1446
#  ОТКРЫТА                                                           197
#  ОТКРЫТИЕ НЕВОЗМОЖНО                                                 1
#  Остановлен CPU в крейте 0                                           4
#  Остановлен CPU в крейте 1                                           7
#  ПЕРЕКЛЮЧЕНИЕ ЛИНИЙ НЕВОЗМОЖНО                                       3
#  ПОЛУЧЕН ЛОЖНЫЙ СИГНАЛ «МП ВКЛЮЧЕН»                                  1
#  ПОЛУЧЕНА КОМАНДА "ДЕБЛОКИРОВАТЬ ЗАЩИТУ"                             1
#  ПОЛУЧЕНА КОМАНДА "ЗАКРЫТЬ АВТОМАТИЧЕСКИ"                         1065
#  ПОЛУЧЕНА КОМАНДА "ЗАКРЫТЬ С АРМ"                                    2
#  ПОЛУЧЕНА КОМАНДА "МАСКИРОВАТЬ ЗАЩИТУ"                               1
#  ПОЛУЧЕНА КОМАНДА "ОТКРЫТЬ АВТОМАТИЧЕСКИ"                         1450
#  ПОЛУЧЕНА КОМАНДА "ОТКРЫТЬ С АРМ"                                    2
#  ПУСК НЕВОЗМОЖЕН                                                     1
#  Перепад давления паров на входе/выходе теплооб...               24885
#  Перепад давления паров на входе/выходе теплооб...                 647
#  Перепад давления пропиленгликоля на насосе Р-21/А                  53
#  Перепад давления пропиленгликоля на насосе Р-21/В                 104
#  Перепад давления пропиленгликоля на насосе Р-22/А                 129
#  Перепад давления пропиленгликоля на насосе Р-22/В                 272
#  Переполнение емкости сбора конденсата Е-1 (LT-...                   3
#  Попытка доступа к запрещенным функциям                             15
#  Р                                                                 612
#  РЕЖИМ - АВТОМАТ ПО ДАВЛЕНИЮ                                         1
#  РЕЖИМ - АВТОМАТ ПО ПОЛОЖЕНИЮ                                        1
#  САМОПРОИЗВОЛЬНОЕ ИЗМЕНЕНИЕ СОСТОЯНИЯ                                1
#  СИГНАЛ ГОТОВНОСТИ СНЯТ                                             81
#  СИГНАЛ ГОТОВНОСТИ УСТАНОВЛЕН                                       82
#  СИГНАЛ ИГНОРИРОВАН                                                 16
#  СИГНАЛ СНЯТ                                                        55
#  СИГНАЛ УСТАНОВЛЕН                                                  29
#  Температура водного конденсата в отстойнике ем...                   1
#  Температура воздуха в модуле конденсации                           53
#  Температура масла на линии возврата в маслоохл...                   3
#  Температура масла на линии забора из маслоотде...                   3
#  Температура на огнепреградителе FA-11                               2
#  Температура на огнепреградителе FA-12                               2
#  Температура на огнепреградителе FA-13                               2
#  Температура на огнепреградителе FA-14                               1
#  Температура поверхности теплообменника АТ-6                        31
#  Температура поверхности теплообменника АТ-8                        28
#  Температура пропиленгликоля в емкости Е-112                       191
#  Температура пропиленгликоля в емости Е-111                         54
#  Температура углеводородного конденсата в емкос...                   1
#  Температура фреона на входе в маслоотделитель ...                   3
#  УРП находится в местном режиме управления                          10
#  Уровень углеводородного конденсата в емкости Е-1                   29
#  Уровень хладоносителя в емкости Е-111                               2
#  Уровень хладоносителя в емкости Е-112                               4
#  Уставка процента открытия заслонки V-21, %                          1
#  Уставка процента открытия заслонки V-3, %                           2
#  Шкаф закрыт                                                        11
#  Шкаф открыт                                                        13
#
#                                                     Квитировать  Сообщение  \
# m0
#  Нажата кнопка маскировать сигнал: Отсутствие а...            1          1
#  Низкое давление на линии всасывания по датчику              67         67
#  Низкое давление на линии всасывания по реле                 16         16
#  Низкое давление на линии подачи масла по реле                5          5
#  ОТКЛЮЧЕН                                                  5400       5400
#  ОТКРЫВАЕТСЯ                                                127        127
#  ОТКРЫВАЕТСЯ В РЕЖИМЕ ИМИТАЦИИ                                5          5
#  ОТКРЫТ                                                    1446       1446
#  ОТКРЫТА                                                    197        197
#  ОТКРЫТИЕ НЕВОЗМОЖНО                                          1          1
#  Остановлен CPU в крейте 0                                    4          4
#  Остановлен CPU в крейте 1                                    7          7
#  ПЕРЕКЛЮЧЕНИЕ ЛИНИЙ НЕВОЗМОЖНО                                3          3
#  ПОЛУЧЕН ЛОЖНЫЙ СИГНАЛ «МП ВКЛЮЧЕН»                           1          1
#  ПОЛУЧЕНА КОМАНДА "ДЕБЛОКИРОВАТЬ ЗАЩИТУ"                      1          1
#  ПОЛУЧЕНА КОМАНДА "ЗАКРЫТЬ АВТОМАТИЧЕСКИ"                  1065       1065
#  ПОЛУЧЕНА КОМАНДА "ЗАКРЫТЬ С АРМ"                             2          2
#  ПОЛУЧЕНА КОМАНДА "МАСКИРОВАТЬ ЗАЩИТУ"                        1          1
#  ПОЛУЧЕНА КОМАНДА "ОТКРЫТЬ АВТОМАТИЧЕСКИ"                  1450       1450
#  ПОЛУЧЕНА КОМАНДА "ОТКРЫТЬ С АРМ"                             2          2
#  ПУСК НЕВОЗМОЖЕН                                              1          1
#  Перепад давления паров на входе/выходе теплооб...        24885      24885
#  Перепад давления паров на входе/выходе теплооб...          647        647
#  Перепад давления пропиленгликоля на насосе Р-21/А           53         53
#  Перепад давления пропиленгликоля на насосе Р-21/В          104        104
#  Перепад давления пропиленгликоля на насосе Р-22/А          129        129
#  Перепад давления пропиленгликоля на насосе Р-22/В          272        272
#  Переполнение емкости сбора конденсата Е-1 (LT-...            3          3
#  Попытка доступа к запрещенным функциям                      15         15
#  Р                                                          612        612
#  РЕЖИМ - АВТОМАТ ПО ДАВЛЕНИЮ                                  1          1
#  РЕЖИМ - АВТОМАТ ПО ПОЛОЖЕНИЮ                                 1          1
#  САМОПРОИЗВОЛЬНОЕ ИЗМЕНЕНИЕ СОСТОЯНИЯ                         1          1
#  СИГНАЛ ГОТОВНОСТИ СНЯТ                                      81         81
#  СИГНАЛ ГОТОВНОСТИ УСТАНОВЛЕН                                82         82
#  СИГНАЛ ИГНОРИРОВАН                                          16         16
#  СИГНАЛ СНЯТ                                                 55         55
#  СИГНАЛ УСТАНОВЛЕН                                           29         29
#  Температура водного конденсата в отстойнике ем...            1          1
#  Температура воздуха в модуле конденсации                    53         53
#  Температура масла на линии возврата в маслоохл...            3          3
#  Температура масла на линии забора из маслоотде...            3          3
#  Температура на огнепреградителе FA-11                        2          2
#  Температура на огнепреградителе FA-12                        2          2
#  Температура на огнепреградителе FA-13                        2          2
#  Температура на огнепреградителе FA-14                        1          1
#  Температура поверхности теплообменника АТ-6                 31         31
#  Температура поверхности теплообменника АТ-8                 28         28
#  Температура пропиленгликоля в емкости Е-112                191        191
#  Температура пропиленгликоля в емости Е-111                  54         54
#  Температура углеводородного конденсата в емкос...            1          1
#  Температура фреона на входе в маслоотделитель ...            3          3
#  УРП находится в местном режиме управления                   10         10
#  Уровень углеводородного конденсата в емкости Е-1            29         29
#  Уровень хладоносителя в емкости Е-111                        2          2
#  Уровень хладоносителя в емкости Е-112                        4          4
#  Уставка процента открытия заслонки V-21, %                   1          1
#  Уставка процента открытия заслонки V-3, %                    2          2
#  Шкаф закрыт                                                 11         11
#  Шкаф открыт                                                 13         13
#
#                                                     component     m1   m2  m3  \
# m0
#  Нажата кнопка маскировать сигнал: Отсутствие а...          1      0    0   0
#  Низкое давление на линии всасывания по датчику            67     67    0   0
#  Низкое давление на линии всасывания по реле               16     16    0   0
#  Низкое давление на линии подачи масла по реле              5      5    5   0
#  ОТКЛЮЧЕН                                                5400      1    0   0
#  ОТКРЫВАЕТСЯ                                              127      0    0   0
#  ОТКРЫВАЕТСЯ В РЕЖИМЕ ИМИТАЦИИ                              5      0    0   0
#  ОТКРЫТ                                                  1446      0    0   0
#  ОТКРЫТА                                                  197      0    0   0
#  ОТКРЫТИЕ НЕВОЗМОЖНО                                        1      1    0   0
#  Остановлен CPU в крейте 0                                  4      0    0   0
#  Остановлен CPU в крейте 1                                  7      0    0   0
#  ПЕРЕКЛЮЧЕНИЕ ЛИНИЙ НЕВОЗМОЖНО                              3      3    3   0
#  ПОЛУЧЕН ЛОЖНЫЙ СИГНАЛ «МП ВКЛЮЧЕН»                         1      0    0   0
#  ПОЛУЧЕНА КОМАНДА "ДЕБЛОКИРОВАТЬ ЗАЩИТУ"                    1      0    0   0
#  ПОЛУЧЕНА КОМАНДА "ЗАКРЫТЬ АВТОМАТИЧЕСКИ"                1065      0    0   0
#  ПОЛУЧЕНА КОМАНДА "ЗАКРЫТЬ С АРМ"                           2      0    0   0
#  ПОЛУЧЕНА КОМАНДА "МАСКИРОВАТЬ ЗАЩИТУ"                      1      0    0   0
#  ПОЛУЧЕНА КОМАНДА "ОТКРЫТЬ АВТОМАТИЧЕСКИ"                1450      0    0   0
#  ПОЛУЧЕНА КОМАНДА "ОТКРЫТЬ С АРМ"                           2      0    0   0
#  ПУСК НЕВОЗМОЖЕН                                            1      1    0   0
#  Перепад давления паров на входе/выходе теплооб...      24885  24885    9   1
#  Перепад давления паров на входе/выходе теплооб...        647    647    9   0
#  Перепад давления пропиленгликоля на насосе Р-21/А         53     53    1   0
#  Перепад давления пропиленгликоля на насосе Р-21/В        104    104    5   0
#  Перепад давления пропиленгликоля на насосе Р-22/А        129    129    4   0
#  Перепад давления пропиленгликоля на насосе Р-22/В        272    272    2   0
#  Переполнение емкости сбора конденсата Е-1 (LT-...          3      3    3   0
#  Попытка доступа к запрещенным функциям                    15      0    0   0
#  Р                                                        612    612  608   7
#  РЕЖИМ - АВТОМАТ ПО ДАВЛЕНИЮ                                1      0    0   0
#  РЕЖИМ - АВТОМАТ ПО ПОЛОЖЕНИЮ                               1      0    0   0
#  САМОПРОИЗВОЛЬНОЕ ИЗМЕНЕНИЕ СОСТОЯНИЯ                       1      1    0   0
#  СИГНАЛ ГОТОВНОСТИ СНЯТ                                    81      0    0   0
#  СИГНАЛ ГОТОВНОСТИ УСТАНОВЛЕН                              82      0    0   0
#  СИГНАЛ ИГНОРИРОВАН                                        16     16    0   0
#  СИГНАЛ СНЯТ                                               55      0    0   0
#  СИГНАЛ УСТАНОВЛЕН                                         29      0    0   0
#  Температура водного конденсата в отстойнике ем...          1      1    0   0
#  Температура воздуха в модуле конденсации                  53     53    0   0
#  Температура масла на линии возврата в маслоохл...          3      3    2   0
#  Температура масла на линии забора из маслоотде...          3      3    2   0
#  Температура на огнепреградителе FA-11                      2      2    0   0
#  Температура на огнепреградителе FA-12                      2      2    0   0
#  Температура на огнепреградителе FA-13                      2      2    0   0
#  Температура на огнепреградителе FA-14                      1      1    0   0
#  Температура поверхности теплообменника АТ-6               31     31    0   0
#  Температура поверхности теплообменника АТ-8               28     28    0   0
#  Температура пропиленгликоля в емкости Е-112              191    191    1   0
#  Температура пропиленгликоля в емости Е-111                54     54    4   0
#  Температура углеводородного конденсата в емкос...          1      1    0   0
#  Температура фреона на входе в маслоотделитель ...          3      3    2   0
#  УРП находится в местном режиме управления                 10      0    0   0
#  Уровень углеводородного конденсата в емкости Е-1          29     29    7   3
#  Уровень хладоносителя в емкости Е-111                      2      2    1   0
#  Уровень хладоносителя в емкости Е-112                      4      4    2   0
#  Уставка процента открытия заслонки V-21, %                 1      1    1   0
#  Уставка процента открытия заслонки V-3, %                  2      2    1   0
#  Шкаф закрыт                                               11      0    0   0
#  Шкаф открыт                                               13      0    0   0
#
#                                                     m4   temp
# m0
#  Нажата кнопка маскировать сигнал: Отсутствие а...   0      1
#  Низкое давление на линии всасывания по датчику      0     67
#  Низкое давление на линии всасывания по реле         0     16
#  Низкое давление на линии подачи масла по реле       0      5
#  ОТКЛЮЧЕН                                            0   5400
#  ОТКРЫВАЕТСЯ                                         0    127
#  ОТКРЫВАЕТСЯ В РЕЖИМЕ ИМИТАЦИИ                       0      5
#  ОТКРЫТ                                              0   1446
#  ОТКРЫТА                                             0    197
#  ОТКРЫТИЕ НЕВОЗМОЖНО                                 0      1
#  Остановлен CPU в крейте 0                           0      4
#  Остановлен CPU в крейте 1                           0      7
#  ПЕРЕКЛЮЧЕНИЕ ЛИНИЙ НЕВОЗМОЖНО                       0      3
#  ПОЛУЧЕН ЛОЖНЫЙ СИГНАЛ «МП ВКЛЮЧЕН»                  0      1
#  ПОЛУЧЕНА КОМАНДА "ДЕБЛОКИРОВАТЬ ЗАЩИТУ"             0      1
#  ПОЛУЧЕНА КОМАНДА "ЗАКРЫТЬ АВТОМАТИЧЕСКИ"            0   1065
#  ПОЛУЧЕНА КОМАНДА "ЗАКРЫТЬ С АРМ"                    0      2
#  ПОЛУЧЕНА КОМАНДА "МАСКИРОВАТЬ ЗАЩИТУ"               0      1
#  ПОЛУЧЕНА КОМАНДА "ОТКРЫТЬ АВТОМАТИЧЕСКИ"            0   1450
#  ПОЛУЧЕНА КОМАНДА "ОТКРЫТЬ С АРМ"                    0      2
#  ПУСК НЕВОЗМОЖЕН                                     0      1
#  Перепад давления паров на входе/выходе теплооб...   0  24885
#  Перепад давления паров на входе/выходе теплооб...   0    647
#  Перепад давления пропиленгликоля на насосе Р-21/А   0     53
#  Перепад давления пропиленгликоля на насосе Р-21/В   0    104
#  Перепад давления пропиленгликоля на насосе Р-22/А   0    129
#  Перепад давления пропиленгликоля на насосе Р-22/В   0    272
#  Переполнение емкости сбора конденсата Е-1 (LT-...   0      3
#  Попытка доступа к запрещенным функциям              0     15
#  Р                                                   7    612
#  РЕЖИМ - АВТОМАТ ПО ДАВЛЕНИЮ                         0      1
#  РЕЖИМ - АВТОМАТ ПО ПОЛОЖЕНИЮ                        0      1
#  САМОПРОИЗВОЛЬНОЕ ИЗМЕНЕНИЕ СОСТОЯНИЯ                0      1
#  СИГНАЛ ГОТОВНОСТИ СНЯТ                              0     81
#  СИГНАЛ ГОТОВНОСТИ УСТАНОВЛЕН                        0     82
#  СИГНАЛ ИГНОРИРОВАН                                  0     16
#  СИГНАЛ СНЯТ                                         0     55
#  СИГНАЛ УСТАНОВЛЕН                                   0     29
#  Температура водного конденсата в отстойнике ем...   0      1
#  Температура воздуха в модуле конденсации            0     53
#  Температура масла на линии возврата в маслоохл...   0      3
#  Температура масла на линии забора из маслоотде...   0      3
#  Температура на огнепреградителе FA-11               0      2
#  Температура на огнепреградителе FA-12               0      2
#  Температура на огнепреградителе FA-13               0      2
#  Температура на огнепреградителе FA-14               0      1
#  Температура поверхности теплообменника АТ-6         0     31
#  Температура поверхности теплообменника АТ-8         0     28
#  Температура пропиленгликоля в емкости Е-112         0    191
#  Температура пропиленгликоля в емости Е-111          0     54
#  Температура углеводородного конденсата в емкос...   0      1
#  Температура фреона на входе в маслоотделитель ...   0      3
#  УРП находится в местном режиме управления           0     10
#  Уровень углеводородного конденсата в емкости Е-1    0     29
#  Уровень хладоносителя в емкости Е-111               0      2
#  Уровень хладоносителя в емкости Е-112               0      4
#  Уставка процента открытия заслонки V-21, %          0      1
#  Уставка процента открытия заслонки V-3, %           0      2
#  Шкаф закрыт                                         0     11
#  Шкаф открыт                                         0     13

# %%
df_fin.groupby("m0").count().head(60)
# Out:
#                                                Время срабатывания  \
# m0
#                                                                 9
#  80                                                            44
#  81                                                            43
#  LT-911                                                         7
#  LT-951                                                         6
#  LT-961                                                        18
#  ModBus RTU                                                    79
#  PDT-901                                                        7
#  PDT-902                                                        7
#  PDT-985                                                       12
#  PDT-986                                                       12
#  PDT-995                                                       27
#  PDT-996                                                       30
#  PT-903                                                        11
#  PT-904                                                        11
#  PT-911                                                        11
#  PT-912                                                        11
#  PT-941                                                        11
#  PT-946                                                         7
#  PT-951                                                        11
#  PT-956                                                         7
#  PT-971                                                        21
#  PT-976                                                        33
#  PT-997                                                        33
#  QTV-21                                                         4
#  QTV-22                                                         3
#  QTV-23                                                         3
#  QTV-24                                                         3
#  QTV-3                                                          4
#  QTV-4                                                          3
#  SB-926                                                         4
#  SB-927                                                         4
#  TT-901                                                        11
#  TT-902                                                         7
#  TT-903                                                         9
#  TT-904                                                         8
#  TT-905                                                         9
#  TT-911                                                         5
#  TT-912                                                         4
#  TT-913                                                         4
#  TT-914                                                         4
#  TT-915                                                         4
#  TT-916                                                         4
#  TT-917 Температура на огнепреградителе FA-14                   4
#  TT-918                                                         4
#  TT-941                                                        12
#  TT-942                                                        12
#  TT-943                                                        18
#  TT-961                                                         7
#  TT-981                                                        24
#  А                                                              5
#  АВАРИЯ ДЕБЛОКИРОВАНА                                          30
#  АВАРИЯ ПРИВОДА                                                70
#  БЛОКИРОВКА УПРАВЛЕНИЯ ЗАКРЫТИЯ                                 1
#  В ПРОМЕЖУТОЧНОМ ПОЛОЖЕНИИ                                    113
#  ВКЛЮЧАЕТСЯ                                                    58
#  ВКЛЮЧЕН                                                     5372
#  ВКЛЮЧЕНИЕ ПРОЦЕДУРЫ ОТЛОЖЕННОГО ПУСКА                          1
#  ВЫКЛЮЧАЕТСЯ                                                   53
#  ВЫПОЛНЕН ПУСК ПО МЕСТУ                                       102
#
#                                                Квитировать  Сообщение  \
# m0
#                                                          9          9
#  80                                                     44         44
#  81                                                     43         43
#  LT-911                                                  7          7
#  LT-951                                                  6          6
#  LT-961                                                 18         18
#  ModBus RTU                                             79         79
#  PDT-901                                                 7          7
#  PDT-902                                                 7          7
#  PDT-985                                                12         12
#  PDT-986                                                12         12
#  PDT-995                                                27         27
#  PDT-996                                                30         30
#  PT-903                                                 11         11
#  PT-904                                                 11         11
#  PT-911                                                 11         11
#  PT-912                                                 11         11
#  PT-941                                                 11         11
#  PT-946                                                  7          7
#  PT-951                                                 11         11
#  PT-956                                                  7          7
#  PT-971                                                 21         21
#  PT-976                                                 33         33
#  PT-997                                                 33         33
#  QTV-21                                                  4          4
#  QTV-22                                                  3          3
#  QTV-23                                                  3          3
#  QTV-24                                                  3          3
#  QTV-3                                                   4          4
#  QTV-4                                                   3          3
#  SB-926                                                  4          4
#  SB-927                                                  4          4
#  TT-901                                                 11         11
#  TT-902                                                  7          7
#  TT-903                                                  9          9
#  TT-904                                                  8          8
#  TT-905                                                  9          9
#  TT-911                                                  5          5
#  TT-912                                                  4          4
#  TT-913                                                  4          4
#  TT-914                                                  4          4
#  TT-915                                                  4          4
#  TT-916                                                  4          4
#  TT-917 Температура на огнепреградителе FA-14            4          4
#  TT-918                                                  4          4
#  TT-941                                                 12         12
#  TT-942                                                 12         12
#  TT-943                                                 18         18
#  TT-961                                                  7          7
#  TT-981                                                 24         24
#  А                                                       5          5
#  АВАРИЯ ДЕБЛОКИРОВАНА                                   30         30
#  АВАРИЯ ПРИВОДА                                         70         70
#  БЛОКИРОВКА УПРАВЛЕНИЯ ЗАКРЫТИЯ                          1          1
#  В ПРОМЕЖУТОЧНОМ ПОЛОЖЕНИИ                             113        113
#  ВКЛЮЧАЕТСЯ                                             58         58
#  ВКЛЮЧЕН                                              5372       5372
#  ВКЛЮЧЕНИЕ ПРОЦЕДУРЫ ОТЛОЖЕННОГО ПУСКА                   1          1
#  ВЫКЛЮЧАЕТСЯ                                            53         53
#  ВЫПОЛНЕН ПУСК ПО МЕСТУ                                102        102
#
#                                                component  m1  m2  m3  m4  temp
# m0
#                                                        9   3   0   0   0     9
#  80                                                   44   0   0   0   0    44
#  81                                                   43   0   0   0   0    43
#  LT-911                                                7   7   7   7   0     7
#  LT-951                                                6   6   6   6   0     6
#  LT-961                                               18  18  18  18   0    18
#  ModBus RTU                                           79  79  79   0   0    79
#  PDT-901                                               7   7   7   7   0     7
#  PDT-902                                               7   7   7   7   0     7
#  PDT-985                                              12  12  12  12   0    12
#  PDT-986                                              12  12  12  12   0    12
#  PDT-995                                              27  27  27  27   0    27
#  PDT-996                                              30  30  30  30   0    30
#  PT-903                                               11  11  11  11   0    11
#  PT-904                                               11  11  11  11   0    11
#  PT-911                                               11  11  11  11   0    11
#  PT-912                                               11  11  11  11   0    11
#  PT-941                                               11  11  11  11   0    11
#  PT-946                                                7   7   7   7   0     7
#  PT-951                                               11  11  11  11   0    11
#  PT-956                                                7   7   7   7   0     7
#  PT-971                                               21  21  21  21   0    21
#  PT-976                                               33  33  33  33   0    33
#  PT-997                                               33  33  33  33   0    33
#  QTV-21                                                4   4   4   4   4     4
#  QTV-22                                                3   3   3   3   3     3
#  QTV-23                                                3   3   3   3   3     3
#  QTV-24                                                3   3   3   3   3     3
#  QTV-3                                                 4   4   4   4   4     4
#  QTV-4                                                 3   3   3   3   3     3
#  SB-926                                                4   4   4   4   4     4
#  SB-927                                                4   4   4   4   4     4
#  TT-901                                               11  11  11  11   0    11
#  TT-902                                                7   7   7   7   0     7
#  TT-903                                                9   9   9   9   0     9
#  TT-904                                                8   8   8   8   0     8
#  TT-905                                                9   9   9   9   0     9
#  TT-911                                                5   5   5   5   0     5
#  TT-912                                                4   4   4   4   0     4
#  TT-913                                                4   4   4   4   0     4
#  TT-914                                                4   4   4   4   0     4
#  TT-915                                                4   4   4   4   0     4
#  TT-916                                                4   4   4   4   0     4
#  TT-917 Температура на огнепреградителе FA-14          4   4   4   0   0     4
#  TT-918                                                4   4   4   4   0     4
#  TT-941                                               12  12  12  12   0    12
#  TT-942                                               12  12  12  12   0    12
#  TT-943                                               18  18  18  18   0    18
#  TT-961                                                7   7   7   7   0     7
#  TT-981                                               24  24  24  24   0    24
#  А                                                     5   5   4   0   0     5
#  АВАРИЯ ДЕБЛОКИРОВАНА                                 30   0   0   0   0    30
#  АВАРИЯ ПРИВОДА                                       70   0   0   0   0    70
#  БЛОКИРОВКА УПРАВЛЕНИЯ ЗАКРЫТИЯ                        1   0   0   0   0     1
#  В ПРОМЕЖУТОЧНОМ ПОЛОЖЕНИИ                           113   0   0   0   0   113
#  ВКЛЮЧАЕТСЯ                                           58   0   0   0   0    58
#  ВКЛЮЧЕН                                            5372   0   0   0   0  5372
#  ВКЛЮЧЕНИЕ ПРОЦЕДУРЫ ОТЛОЖЕННОГО ПУСКА                 1   0   0   0   0     1
#  ВЫКЛЮЧАЕТСЯ                                          53   0   0   0   0    53
#  ВЫПОЛНЕН ПУСК ПО МЕСТУ                              102   0   0   0   0   102

# %%
df_fin.m0.value_counts().head(50)
# Out:
#  Перепад давления паров на входе/выходе теплообменников АТ-5, АТ-6        24885
#  ОТКЛЮЧЕН                                                                  5400
#  ВКЛЮЧЕН                                                                   5372
#  КОМАНДА - ОТКЛЮЧИТЬ АВТОМАТИЧЕСКИ                                         5160
#  КОМАНДА - ВКЛЮЧИТЬ АВТОМАТИЧЕСКИ                                          4684
#  ЗАДЕРЖКА                                                                  2891
#  ЗАДЕРЖКА СНЯТА                                                            2889
#  Защита компрессора К-111 от низкого давления масла                        2362
#  ПОЛУЧЕНА КОМАНДА "ОТКРЫТЬ АВТОМАТИЧЕСКИ"                                  1450
#  ОТКРЫТ                                                                    1446
#  Задвижка V-3                                                              1432
#  ЗАКРЫТ                                                                    1078
#  ПОЛУЧЕНА КОМАНДА "ЗАКРЫТЬ АВТОМАТИЧЕСКИ"                                  1065
#  ЗАКРЫТА                                                                    952
#  НЕ ЗАКРЫТА                                                                 793
#  НАЗНАЧЕН РЕЖИМ ОСНОВНОЙ                                                    767
#  Восстановлена связь с крейтом А3 (Основной канал)                          754
#  НАЗНАЧЕН РЕЖИМ РЕЗЕРВНЫЙ                                                   722
#  Защита компрессора К-112 от низкого давления масла                         703
#  Перепад давления паров на входе/выходе теплообменников АТ-7, АТ-8          647
#  Р                                                                          612
#  КОМАНДА - ВКЛЮЧИТЬ РЕЗЕРВНЫЙ АГРЕГАТ КАК ДОПОЛНИТЕЛЬНЫЙ АВТОМАТИЧЕСКИ      546
#  Давление паров на входе вентиляторов VD-103/A, VD-103/B                    533
#  НАЗНАЧИТЬ РЕЖИМ ОСНОВНОЙ АВТОМАТИЧЕСКИ                                     529
#  НАЗНАЧИТЬ РЕЖИМ РЕЗЕРВНЫЙ АВТОМАТИЧЕСКИ                                    509
#  Коммутатор А7                                                              364
#  Коммутатор А9                                                              358
#  Перепад давления пропиленгликоля на насосе Р-22/В                          272
#  ЕСТЬ НАПРЯЖЕНИЕ В СХЕМЕ УПРАВЛЕНИЯ                                         264
#  НЕТ НАПРЯЖЕНИЯ В СХЕМЕ УПРАВЛЕНИЯ                                          235
#  Задвижка V-22                                                              229
#  Вентилятор VA-903/A                                                        225
#  КОМАНДА - ЗАКРЫТЬ АВТОМАТИЧЕСКИ                                            204
#  ОТКРЫТА                                                                    197
#  Температура пропиленгликоля в емкости Е-112                                191
#  КЛЮЧ В РЕЖИМЕ УПРАВЛЕНИЯ ПО ДИСТАНЦИИ                                      176
#  КЛЮЧ В РЕЖИМЕ УПРАВЛЕНИЯ ПО МЕСТУ                                          160
#  Давление фреона на входе компрессора К-101                                 160
#  Защита компрессора К-113 от низкого давления масла                         146
#  НЕИСПРАВЕН                                                                 136
#  Перепад давления пропиленгликоля на насосе Р-22/А                          129
#  ОТКРЫВАЕТСЯ                                                                127
#  ЗАКРЫВАЕТСЯ                                                                126
#  КОМАНДА - ДЕБЛОКИРОВАТЬ НЕИСПРАВНОСТЬ С АРМ                                116
#  В ПРОМЕЖУТОЧНОМ ПОЛОЖЕНИИ                                                  113
#  Задвижка V-24                                                              112
#  НЕ ОТКРЫТА                                                                 111
#  ВЫПОЛНЕН СТОП ПО МЕСТУ                                                     106
#  НЕИСПРАВНОСТЬ ДЕБЛОКИРОВАНА                                                106
#  Перепад давления пропиленгликоля на насосе Р-21/В                          104
# Name: m0, dtype: int64

# %%
df_fin["temp"] = df_fin.m0 == " ВКЛЮЧЕН"
# df_fin["temp"] = np.where('PT-912	' in df_fin.m0, 1, 0)
# df_fin["temp"] = np.where('Р' in df_fin.m0, 1, 0)
#np.where(x > 0, 12, x)
df_fin["temp"]
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 76026    False
# 76027    False
# 76028    False
# 76029    False
# 76030    False
# Name: temp, Length: 76031, dtype: bool

# %%
df_fin.groupby("temp").count()
# Out:
#        Время срабатывания  Квитировать  Сообщение  component     m0     m1  \
# temp
# False               70659        70659      70659      70659  70619  35193
# True                 5372         5372       5372       5372   5372      0
#
#          m2   m3  m4
# temp
# False  4227  591  36
# True      0    0   0

# %%
df_fin["temp"] = df_fin.m0 == " НЕТ НАПРЯЖЕНИЯ В СХЕМЕ УПРАВЛЕНИЯ"
# df_fin["temp"] = np.where('PT-912	' in df_fin.m0, 1, 0)
# df_fin["temp"] = np.where('Р' in df_fin.m0, 1, 0)
#np.where(x > 0, 12, x)
df_fin["temp"]
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 76026    False
# 76027    False
# 76028    False
# 76029    False
# 76030    False
# Name: temp, Length: 76031, dtype: bool

# %%
df_fin.groupby("temp").count()
# Out:
#        Время срабатывания  Квитировать  Сообщение  component     m0     m1  \
# temp
# False               75796        75796      75796      75796  75756  35193
# True                  235          235        235        235    235      0
#
#          m2   m3  m4
# temp
# False  4227  591  36
# True      0    0   0

# %%
# df_fin["temp"] = np.where(df_fin.m0 == " НЕТ НАПРЯЖЕНИЯ В СХЕМЕ УПРАВЛЕНИЯ", 1, 0)

# %%
for i in range(10):
    print(df_fin.m0[i])
# Out:
#  ВКЛЮЧЕН
#  КОМАНДА - ВКЛЮЧИТЬ РЕЗЕРВНЫЙ АГРЕГАТ КАК ДОПОЛНИТЕЛЬНЫЙ АВТОМАТИЧЕСКИ
#  НАЗНАЧЕН РЕЖИМ ОСНОВНОЙ
#  НАЗНАЧИТЬ РЕЖИМ ОСНОВНОЙ АВТОМАТИЧЕСКИ
#  ПОЛУЧЕНА КОМАНДА "ОТКРЫТЬ АВТОМАТИЧЕСКИ"
#  ОТКРЫТ
#  ВКЛЮЧЕН
#  НАЗНАЧЕН РЕЖИМ ОСНОВНОЙ
#  НАЗНАЧИТЬ РЕЖИМ ОСНОВНОЙ АВТОМАТИЧЕСКИ
#  КОМАНДА - ВКЛЮЧИТЬ РЕЗЕРВНЫЙ АГРЕГАТ КАК ДОПОЛНИТЕЛЬНЫЙ АВТОМАТИЧЕСКИ

# %%
plt.figure(figsize=(20, 10))
plt.plot(df_fin["Время срабатывания"], df_fin["temp"])
plt.title("Частота по времени")
plt.xlabel("Время")
plt.ylabel("Значение")
# Out:
# Text(0, 0.5, 'Значение')
